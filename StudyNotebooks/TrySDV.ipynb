# %%
from sdv.datasets.demo import download_demo
from sdv.single_table import GaussianCopulaSynthesizer, CopulaGANSynthesizer, CTGANSynthesizer, TVAESynthesizer
from sdv.evaluation.single_table import evaluate_quality
from sdv.evaluation.single_table import get_column_plot
from sdv.metadata import SingleTableMetadata

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
real_data, metadata = download_demo(
    modality='single_table',
    dataset_name='fake_hotel_guests'
)

numerical_dist_list = [
    "norm",
    "beta",
    "truncnorm",
    "gamma",
    "uniform",
    "gaussian_kde",
]

synthesizer = GaussianCopulaSynthesizer(metadata)
synthesizer.fit(data=real_data)

synthetic_data = synthesizer.sample(num_rows=500)

quality_report = evaluate_quality(
    real_data,
    synthetic_data,
    metadata
)
# Out:
# Creating report: 100%|██████████| 4/4 [00:00<00:00, 57.60it/s]
# Overall Quality Score: 87.7%
#
# Properties:
# Column Shapes: 87.45%
# Column Pair Trends: 87.94%

# %%
synthesizer = CopulaGANSynthesizer(metadata)
synthesizer.fit(data=real_data)

synthetic_data = synthesizer.sample(num_rows=500)

quality_report = evaluate_quality(
    real_data,
    synthetic_data,
    metadata
)
# Out:
# c:\Users\kdgh685\OneDrive - AZCollaboration\Escritorio\Jose\TabularDataGAN\venv\lib\site-packages\rdt\transformers\base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# c:\Users\kdgh685\OneDrive - AZCollaboration\Escritorio\Jose\TabularDataGAN\venv\lib\site-packages\rdt\transformers\base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# c:\Users\kdgh685\OneDrive - AZCollaboration\Escritorio\Jose\TabularDataGAN\venv\lib\site-packages\rdt\transformers\base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# c:\Users\kdgh685\OneDrive - AZCollaboration\Escritorio\Jose\TabularDataGAN\venv\lib\site-packages\rdt\transformers\base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# Creating report: 100%|██████████| 4/4 [00:00<00:00, 31.67it/s]
# Overall Quality Score: 81.65%
#
# Properties:
# Column Shapes: 81.77%
# Column Pair Trends: 81.53%

# %%
synthesizer = CTGANSynthesizer(metadata)
synthesizer.fit(data=real_data)

synthetic_data = synthesizer.sample(num_rows=500)

quality_report = evaluate_quality(
    real_data,
    synthetic_data,
    metadata
)
# Out:
# c:\Users\kdgh685\OneDrive - AZCollaboration\Escritorio\Jose\TabularDataGAN\venv\lib\site-packages\rdt\transformers\base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# c:\Users\kdgh685\OneDrive - AZCollaboration\Escritorio\Jose\TabularDataGAN\venv\lib\site-packages\rdt\transformers\base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# c:\Users\kdgh685\OneDrive - AZCollaboration\Escritorio\Jose\TabularDataGAN\venv\lib\site-packages\rdt\transformers\base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# c:\Users\kdgh685\OneDrive - AZCollaboration\Escritorio\Jose\TabularDataGAN\venv\lib\site-packages\rdt\transformers\base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# Creating report: 100%|██████████| 4/4 [00:00<00:00, 31.55it/s]
# Overall Quality Score: 82.71%
#
# Properties:
# Column Shapes: 84.26%
# Column Pair Trends: 81.16%

# %%
synthesizer = TVAESynthesizer(metadata)
synthesizer.fit(data=real_data)

synthetic_data = synthesizer.sample(num_rows=500)

quality_report = evaluate_quality(
    real_data,
    synthetic_data,
    metadata
)
# Out:
# c:\Users\kdgh685\OneDrive - AZCollaboration\Escritorio\Jose\TabularDataGAN\venv\lib\site-packages\rdt\transformers\base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# c:\Users\kdgh685\OneDrive - AZCollaboration\Escritorio\Jose\TabularDataGAN\venv\lib\site-packages\rdt\transformers\base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# c:\Users\kdgh685\OneDrive - AZCollaboration\Escritorio\Jose\TabularDataGAN\venv\lib\site-packages\rdt\transformers\base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# c:\Users\kdgh685\OneDrive - AZCollaboration\Escritorio\Jose\TabularDataGAN\venv\lib\site-packages\rdt\transformers\base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# Creating report: 100%|██████████| 4/4 [00:00<00:00, 36.73it/s]
# Overall Quality Score: 87.53%
#
# Properties:
# Column Shapes: 88.87%
# Column Pair Trends: 86.18%

# %% [markdown]
# # Maternal dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("Data/Maternal Health Risk Data Set.csv")
numeric_cols = ['Age', 'SystolicBP', 'DiastolicBP', 'BS', 'BodyTemp', 'HeartRate']
df.head(5)
# Out:
#    Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80  15.0      98.0         86  high risk
# 1   35         140           90  13.0      98.0         70  high risk
# 2   29          90           70   8.0     100.0         80  high risk
# 3   30         140           85   7.0      98.0         70  high risk
# 4   35         120           60   6.1      98.0         76   low risk

# %%
metadata = Metadata.detect_from_dataframe(
    data=df,
    table_name='maternal_metadata'
)

# %%
maternal_metadata = {
    "tables": {
        "patient_health_records": {
            "primary_key": None,
            "columns": {
                "Age": {
                    "sdtype": "numerical",
                    "computer_representation": "Integer"
                },
                "SystolicBP": {
                    "sdtype": "numerical",
                    "computer_representation": "Integer"
                },
                "DiastolicBP": {
                    "sdtype": "numerical",
                    "computer_representation": "Integer"
                },
                "BS": {
                    "sdtype": "numerical",
                    "computer_representation": "Float"
                },
                "BodyTemp": {
                    "sdtype": "numerical",
                    "computer_representation": "Float"
                },
                "HeartRate": {
                    "sdtype": "numerical",
                    "computer_representation": "Integer"
                }
            }
        }
    },
    "relationships": [],
    "METADATA_SPEC_VERSION": "V1"
}

# %%
from sdv.metadata import SingleTableMetadata
from sdv.single_table import GaussianCopulaSynthesizer

metadata = SingleTableMetadata()
maternal_metadata = metadata.load_from_dict(maternal_metadata)

# %%
df
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.0      98.0         86  high risk
# 1      35         140           90  13.0      98.0         70  high risk
# 2      29          90           70   8.0     100.0         80  high risk
# 3      30         140           85   7.0      98.0         70  high risk
# 4      35         120           60   6.1      98.0         76   low risk
# ...   ...         ...          ...   ...       ...        ...        ...
# 1009   22         120           60  15.0      98.0         80  high risk
# 1010   55         120           90  18.0      98.0         60  high risk
# 1011   35          85           60  19.0      98.0         86  high risk
# 1012   43         120           90  18.0      98.0         70  high risk
# 1013   32         120           65   6.0     101.0         76   mid risk
#
# [1014 rows x 7 columns]

# %%
synthesizer = GaussianCopulaSynthesizer(metadata)
synthesizer.fit(data=df)

synthetic_data = synthesizer.sample(num_rows=500)

# %%
synthetic_data
# Out:
#                       guest_email  has_rewards room_type  amenities_fee  \
# 0           dsullivan@example.net        False     BASIC           0.29
# 1            steven59@example.org        False    DELUXE           8.15
# 2           brandon15@example.net        False     BASIC          11.65
# 3    humphreyjennifer@example.net        False     BASIC          48.12
# 4         joshuabrown@example.net        False    DELUXE          11.07
# ..                            ...          ...       ...            ...
# 495         donnaodom@example.net        False    DELUXE            NaN
# 496        tammycarey@example.net        False    DELUXE           0.91
# 497             gwebb@example.org         True     BASIC           1.43
# 498         carlnovak@example.com        False     BASIC          48.12
# 499         lwilliams@example.org         True     SUITE          15.72
#
#     checkin_date checkout_date  room_rate  \
# 0     2020-03-27    2020-03-09     135.15
# 1     2020-09-07    2020-06-25     183.24
# 2     2020-03-22    2020-04-01     163.57
# 3     2020-06-04    2020-05-14     127.75
# 4     2020-01-08    2020-01-13     180.12
# ..           ...           ...        ...
# 495   2020-01-14    2020-01-15     276.74
# 496   2020-05-14    2020-03-23     271.57
# 497   2020-03-18    2020-02-27     131.85
# 498   2020-06-29    2020-08-25     367.12
# 499   2020-09-09    2020-08-25     174.21
#
#                                        billing_address   credit_card_number
# 0     90469 Karla Knolls Apt. 781\nSusanberg, CA 70033     5161033759518983
# 1       6108 Carla Ports Apt. 116\nPort Evan, MI 71694  4133047413145475690
# 2    86709 Jeremy Manors Apt. 786\nPort Garychester...        4977328103788
# 3              8906 Bobby Trail\nEast Sandra, NY 43986     3524946844839485
# 4         732 Dennis Lane\nPort Nicholasstad, DE 49786  4446905799576890978
# ..                                                 ...                  ...
# 495      328 Danny Haven Apt. 575\nBrownbury, FM 31800      180069262819334
# 496        48578 Parker Underpass\nBradybury, VA 45723     4716059563401606
# 497  590 Peterson Roads Apt. 892\nLake Phillip, NE ...     3564840847844629
# 498          2854 Steven Haven\nWest Michael, NE 22990  4707209056757331019
# 499             732 Dale Camp\nPort Jennifer, MP 64418      213123330164875
#
# [500 rows x 9 columns]

# %%
quality_report = evaluate_quality(
    df,
    synthetic_data,
    metadata
)
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████████████████████████████████████████████████| 7/7 [00:00<00:00, 339.55it/s]|
# Column Shapes Score: 78.63%
#
# (2/2) Evaluating Column Pair Trends: |███████████████████████████████████████████████| 21/21 [00:00<00:00, 256.37it/s]|
# Column Pair Trends Score: 84.7%
#
# Overall Score (Average): 81.67%

# %%
plt.hist(df["Age"].values, bins=31, alpha=0.6)
plt.hist(synthetic_data["Age"].values, bins=31, alpha=0.6)

plt.show()

plt.hist(df["SystolicBP"].values, bins=31, alpha=0.6)
plt.hist(synthetic_data["SystolicBP"].values, bins=31, alpha=0.6)

plt.show()

plt.hist(df["HeartRate"].values, bins=31, alpha=0.6)
plt.hist(synthetic_data["HeartRate"].values, bins=31, alpha=0.6)

plt.show()
